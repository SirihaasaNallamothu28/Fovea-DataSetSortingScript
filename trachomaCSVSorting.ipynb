# %%
#Tracoma soriting images
#So TF and TI are 1 than the image has both the trachoma stuff
#So TF 1 and TI 1 then image has only that
#If TF and TI are 0 then none

# %%
#one to 1656

# %%
DATADIR = "/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/trachomaoverall"

# %%
DATADIR = "/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/trachomaDatasettfti"

# %%
DATADIR = "/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/healthyEylid"

# %%
fileCSV = "/Users/swathikakarala/Desktop/Sirihaasa/tfti.csv"
#on desktop

# %%
import pandas as pd

# %%
allData =  pd.read_csv(fileCSV,
                       delimiter=',')
allData.head(20) #First 20 rows printed
# Out:
#     key  TF  TI  AddedValues  Paths
# 0     1   0   0            0    NaN
# 1     2   1   0            1    NaN
# 2     3   0   0            0    NaN
# 3     4   0   0            0    NaN
# 4     5   1   0            1    NaN
# 5     6   0   1            1    NaN
# 6     7   0   0            0    NaN
# 7     8   1   1            2    NaN
# 8     9   0   0            0    NaN
# 9    10   1   1            2    NaN
# 10   11   1   0            1    NaN
# 11   12   0   0            0    NaN
# 12   13   0   0            0    NaN
# 13   14   0   0            0    NaN
# 14   15   1   0            1    NaN
# 15   16   1   0            1    NaN
# 16   17   0   0            0    NaN
# 17   18   0   0            0    NaN
# 18   19   0   0            0    NaN
# 19   20   1   0            1    NaN

# %%
normal_path = '/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/healthyEylid'

# %%
tfti_path = '/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/trachomaDatasettfti'

# %%
healthyCSV = '/Users/swathikakarala/Desktop/Sirihaasa/healthyCSV.csv'

# %%
healthData =  pd.read_csv(healthyCSV,
                       delimiter=',')
healthData.head(20)
# Out:
# Empty DataFrame
# Columns: [key, healthyPath]
# Index: []

# %%
trachomafilesCSV = '/Users/swathikakarala/Desktop/Sirihaasa/trachoma.csv'

# %%
trachomafilesCSV  =  pd.read_csv(trachomafilesCSV ,
                       delimiter=',')
trachomafilesCSV .head(20)
# Out:
# Empty DataFrame
# Columns: [key, trachomaTFTIPath]
# Index: []

# %%
#Add and put in new file

# %%
#There will be 1, 2, and 0
#two means bohth of them, 
#1 menans oen of them 
#o mean healthy

# %%
allData.head(25)
# Out:
#     key  TF  TI  AddedValues  Paths
# 0     1   0   0            0    NaN
# 1     2   1   0            1    NaN
# 2     3   0   0            0    NaN
# 3     4   0   0            0    NaN
# 4     5   1   0            1    NaN
# 5     6   0   1            1    NaN
# 6     7   0   0            0    NaN
# 7     8   1   1            2    NaN
# 8     9   0   0            0    NaN
# 9    10   1   1            2    NaN
# 10   11   1   0            1    NaN
# 11   12   0   0            0    NaN
# 12   13   0   0            0    NaN
# 13   14   0   0            0    NaN
# 14   15   1   0            1    NaN
# 15   16   1   0            1    NaN
# 16   17   0   0            0    NaN
# 17   18   0   0            0    NaN
# 18   19   0   0            0    NaN
# 19   20   1   0            1    NaN
# 20   21   0   0            0    NaN
# 21   22   0   0            0    NaN
# 22   23   0   0            0    NaN
# 23   24   1   0            1    NaN
# 24   25   0   0            0    NaN

# %%
#Now read in the values and get the key

# %%
#add.jpg

# %%
allData.applymap(str)
# Out:
#        key TF TI AddedValues Paths
# 0        1  0  0           0   nan
# 1        2  1  0           1   nan
# 2        3  0  0           0   nan
# 3        4  0  0           0   nan
# 4        5  1  0           1   nan
# ...    ... .. ..         ...   ...
# 1651  1652  0  0           0   nan
# 1652  1653  0  0           0   nan
# 1653  1654  0  0           0   nan
# 1654  1655  0  0           0   nan
# 1655  1656  0  0           0   nan
#
# [1656 rows x 5 columns]

# %%
#append the path: pathofOriginal+'/'+image[numberher].jpg 
pathofOriginal = '/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/trachomaoverall/image'

# %%
allData
# Out:
#        key  TF  TI  AddedValues  \
# 0        1   0   0            0
# 1        2   1   0            1
# 2        3   0   0            0
# 3        4   0   0            0
# 4        5   1   0            1
# ...    ...  ..  ..          ...
# 1651  1652   0   0            0
# 1652  1653   0   0            0
# 1653  1654   0   0            0
# 1654  1655   0   0            0
# 1655  1656   0   0            0
#
#                                                   Paths
# 0     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 2     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 3     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 4     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...                                                 ...
# 1651  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1652  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1653  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
# allData['Paths']= '/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/trachomaoverall/image'+allData['key']

# %%
# allData['Paths'] = pathofOriginal+str(allData['key'])+'.jpg'

# %%
allData
# Out:
#        key  TF  TI  AddedValues  \
# 0        1   0   0            0
# 1        2   1   0            1
# 2        3   0   0            0
# 3        4   0   0            0
# 4        5   1   0            1
# ...    ...  ..  ..          ...
# 1651  1652   0   0            0
# 1652  1653   0   0            0
# 1653  1654   0   0            0
# 1654  1655   0   0            0
# 1655  1656   0   0            0
#
#                                                   Paths
# 0     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 2     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 3     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 4     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...                                                 ...
# 1651  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1652  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1653  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
#allData.to_csv(fileCSV, index = False)

# %%
allData['Paths'] = '/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/trachomaoverall/image'

# %%
allData
# Out:
#        key  TF  TI  AddedValues  \
# 0        1   0   0            0
# 1        2   1   0            1
# 2        3   0   0            0
# 3        4   0   0            0
# 4        5   1   0            1
# ...    ...  ..  ..          ...
# 1651  1652   0   0            0
# 1652  1653   0   0            0
# 1653  1654   0   0            0
# 1654  1655   0   0            0
# 1655  1656   0   0            0
#
#                                                   Paths
# 0     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 2     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 3     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 4     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...                                                 ...
# 1651  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1652  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1653  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
#Start over

# %%
allDataNew =  pd.read_csv(fileCSV,
                       delimiter=',')
allDataNew.head(20) #First 20 rows printed
# Out:
#     key  TF  TI  AddedValues  Paths
# 0     1   0   0            0    NaN
# 1     2   1   0            1    NaN
# 2     3   0   0            0    NaN
# 3     4   0   0            0    NaN
# 4     5   1   0            1    NaN
# 5     6   0   1            1    NaN
# 6     7   0   0            0    NaN
# 7     8   1   1            2    NaN
# 8     9   0   0            0    NaN
# 9    10   1   1            2    NaN
# 10   11   1   0            1    NaN
# 11   12   0   0            0    NaN
# 12   13   0   0            0    NaN
# 13   14   0   0            0    NaN
# 14   15   1   0            1    NaN
# 15   16   1   0            1    NaN
# 16   17   0   0            0    NaN
# 17   18   0   0            0    NaN
# 18   19   0   0            0    NaN
# 19   20   1   0            1    NaN

# %%
trail = allDataNew.applymap(str)

# %%
trail
# Out:
#        key TF TI AddedValues Paths
# 0        1  0  0           0   nan
# 1        2  1  0           1   nan
# 2        3  0  0           0   nan
# 3        4  0  0           0   nan
# 4        5  1  0           1   nan
# ...    ... .. ..         ...   ...
# 1651  1652  0  0           0   nan
# 1652  1653  0  0           0   nan
# 1653  1654  0  0           0   nan
# 1654  1655  0  0           0   nan
# 1655  1656  0  0           0   nan
#
# [1656 rows x 5 columns]

# %%
trail['key'] = "image"+trail['key']+'.jpg'

# %%
trail
# Out:
#                           key TF TI AddedValues  \
# 0        imageimages1.jpg.jpg  0  0           0
# 1        imageimages2.jpg.jpg  1  0           1
# 2        imageimages3.jpg.jpg  0  0           0
# 3        imageimages4.jpg.jpg  0  0           0
# 4        imageimages5.jpg.jpg  1  0           1
# ...                       ... .. ..         ...
# 1651  imageimages1652.jpg.jpg  0  0           0
# 1652  imageimages1653.jpg.jpg  0  0           0
# 1653  imageimages1654.jpg.jpg  0  0           0
# 1654  imageimages1655.jpg.jpg  0  0           0
# 1655  imageimages1656.jpg.jpg  0  0           0
#
#                                                   Paths
# 0     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 2     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 3     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 4     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
'/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/trachomaoverall/image'
# Out:
# '/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/trachomaoverall/image'

# %%
trail['Paths']='/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/trachomaoverall/'+ trail['key']

# %%
trail
# Out:
#                           key TF TI AddedValues  \
# 0        imageimages1.jpg.jpg  0  0           0
# 1        imageimages2.jpg.jpg  1  0           1
# 2        imageimages3.jpg.jpg  0  0           0
# 3        imageimages4.jpg.jpg  0  0           0
# 4        imageimages5.jpg.jpg  1  0           1
# ...                       ... .. ..         ...
# 1651  imageimages1652.jpg.jpg  0  0           0
# 1652  imageimages1653.jpg.jpg  0  0           0
# 1653  imageimages1654.jpg.jpg  0  0           0
# 1654  imageimages1655.jpg.jpg  0  0           0
# 1655  imageimages1656.jpg.jpg  0  0           0
#
#                                                   Paths
# 0     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 2     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 3     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 4     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
trail.to_csv(fileCSV,index=False)

# %%
#trail
#If addevlaues are 0 then go to normal
#if addevalues are 1 or two the, greater than 0 go to trachoma

# %%
newera =  pd.read_csv(fileCSV,
                       delimiter=',')
newera.head(20) #First 20 rows printed
# Out:
#                       key  TF  TI  AddedValues  \
# 0    imageimages1.jpg.jpg   0   0            0
# 1    imageimages2.jpg.jpg   1   0            1
# 2    imageimages3.jpg.jpg   0   0            0
# 3    imageimages4.jpg.jpg   0   0            0
# 4    imageimages5.jpg.jpg   1   0            1
# 5    imageimages6.jpg.jpg   0   1            1
# 6    imageimages7.jpg.jpg   0   0            0
# 7    imageimages8.jpg.jpg   1   1            2
# 8    imageimages9.jpg.jpg   0   0            0
# 9   imageimages10.jpg.jpg   1   1            2
# 10  imageimages11.jpg.jpg   1   0            1
# 11  imageimages12.jpg.jpg   0   0            0
# 12  imageimages13.jpg.jpg   0   0            0
# 13  imageimages14.jpg.jpg   0   0            0
# 14  imageimages15.jpg.jpg   1   0            1
# 15  imageimages16.jpg.jpg   1   0            1
# 16  imageimages17.jpg.jpg   0   0            0
# 17  imageimages18.jpg.jpg   0   0            0
# 18  imageimages19.jpg.jpg   0   0            0
# ...

# %%
#trachoma
/Users/swathikakarala/Desktop/Sirihaasa/trachoma.csv

# %%
# trach = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\leftCataracts.csv')
# t_name = trach[trach.labels=="['C']"]['name']  #Using the query method to search every individual column in in labels for N
# #Assigining the value 'name', which is a file path to n name, and putting it in this columns
# trach['Cataracts'] = t_name

# trach

# %%
newera['AddedValues'].values[7]
# Out:
# 2

# %%
# i = 0
# for num in newera['AddedValues'].values[i]:
#     if num==0:
#         newera['Normalpaths'] = newera['Paths'].value[i]
#         i=i+1
#     else:
#         newera['trachomapaths'] = newera['Paths'].value[i]
#         i=i+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-192-df835fd431e1> in <module>
#       1 i = 0
# ----> 2 for num in newera['AddedValues'].values[i]:
#       3     if num==0:
#       4         newera['Normalpaths'] = newera['Paths'].value[i]
#       5         i=i+1
#
# TypeError: 'numpy.int64' object is not iterable

# %%
if newera['AddedValues'] == 0:
    newera['Normalpaths'] = newera['Paths']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-196-454bb03d4b13> in <module>
# ----> 1 if newera['AddedValues'] == 0:
#       2     newera['Normalpaths'] = newera['Paths']
#
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1441     def __nonzero__(self):
#    1442         raise ValueError(
# -> 1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1445         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
newera
# Out:
#                  key  TF  TI  AddedValues  \
# 0        images1.jpg   0   0            0
# 1        images2.jpg   1   0            1
# 2        images3.jpg   0   0            0
# 3        images4.jpg   0   0            0
# 4        images5.jpg   1   0            1
# ...              ...  ..  ..          ...
# 1651  images1652.jpg   0   0            0
# 1652  images1653.jpg   0   0            0
# 1653  images1654.jpg   0   0            0
# 1654  images1655.jpg   0   0            0
# 1655  images1656.jpg   0   0            0
#
#                                                   Paths  Normalpaths  \
# 0     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...          NaN
# 1     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...          NaN
# 2     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...          NaN
# 3     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...          NaN
# 4     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...          NaN
# ...

# %%
newera.head(20)
# Out:
#              key  TF  TI  AddedValues  \
# 0    images1.jpg   0   0            0
# 1    images2.jpg   1   0            1
# 2    images3.jpg   0   0            0
# 3    images4.jpg   0   0            0
# 4    images5.jpg   1   0            1
# 5    images6.jpg   0   1            1
# 6    images7.jpg   0   0            0
# 7    images8.jpg   1   1            2
# 8    images9.jpg   0   0            0
# 9   images10.jpg   1   1            2
# 10  images11.jpg   1   0            1
# 11  images12.jpg   0   0            0
# 12  images13.jpg   0   0            0
# 13  images14.jpg   0   0            0
# 14  images15.jpg   1   0            1
# 15  images16.jpg   1   0            1
# 16  images17.jpg   0   0            0
# 17  images18.jpg   0   0            0
# 18  images19.jpg   0   0            0
# 19  images20.jpg   1   0            1
#
#                                                 Paths  Normalpaths  \
# 0   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...          NaN
# ...

# %%
index = 0
for num in newera['AddedValues'].values[index]:
    newera['AddedValues'].values[index].astype(numpy.int32)
    index=index+1;
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-212-84ffd29d8ce0> in <module>
#       1 index = 0
# ----> 2 for num in newera['AddedValues'].values[index]:
#       3     newera['AddedValues'].values[index].astype(numpy.int32)
#       4     index=index+1;
#
# TypeError: 'numpy.int64' object is not iterable

# %%
import numpy as np

# %%
type(newera['AddedValues'].values[0].astype(np.int32))
# Out:
# numpy.int32

# %%
type(newera['AddedValues'].astype(np.int32))
# Out:
# pandas.core.series.Series

# %%
i = 0
for num in newera['AddedValues'].values[i]:
    
    if num==0:
        newera['Normalpaths'] = newera['Paths'].value[i]
        i=i+1
    else:
        newera['trachomapaths'] = newera['Paths'].value[i]
        i=i+1

# %%
newera['AddedValues'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-199-3b096a2bc4b2> in <module>
# ----> 1 int(newera['AddedValues'])
#
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/pandas/core/series.py in wrapper(self)
#     139         if len(self) == 1:
#     140             return converter(self.iloc[0])
# --> 141         raise TypeError(f"cannot convert the series to {converter}")
#     142
#     143     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>

# %%
type(int(newera['AddedValues'].values[0]))
# Out:
# int

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-209-3b096a2bc4b2> in <module>
# ----> 1 int(newera['AddedValues'])
#
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/pandas/core/series.py in wrapper(self)
#     139         if len(self) == 1:
#     140             return converter(self.iloc[0])
# --> 141         raise TypeError(f"cannot convert the series to {converter}")
#     142
#     143     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>

# %%
l = len(newera.key)

# %%
# index = 0
# while(index<l):
#     if newera['AddedValues'].values[index]==0:
#         newera['Normalpaths'] = newera['Paths'].values[index]
#         index = index+1

# %%
newera

# %%
newera['Normalpaths'].values[0]
# Out:
# '/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/trachomaoverall/images1656.jpg'

# %%
if newera['trachomapaths'].values[0]==0:
    newera['trachomapaths'] = newer['Paths'].values

# %%
newera
# Out:
#                  key  TF  TI  AddedValues  \
# 0        images1.jpg   0   0            0
# 1        images2.jpg   1   0            1
# 2        images3.jpg   0   0            0
# 3        images4.jpg   0   0            0
# 4        images5.jpg   1   0            1
# ...              ...  ..  ..          ...
# 1651  images1652.jpg   0   0            0
# 1652  images1653.jpg   0   0            0
# 1653  images1654.jpg   0   0            0
# 1654  images1655.jpg   0   0            0
# 1655  images1656.jpg   0   0            0
#
#                                                   Paths  \
# 0     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 2     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 3     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 4     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...                                                 ...
# 1651  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
newera['Normalpaths'].values[0]
# Out:
# '/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/trachomaoverall/images1656.jpg'

# %%
newera
# Out:
#                  key  TF  TI  AddedValues  \
# 0        images1.jpg   0   0            0
# 1        images2.jpg   1   0            1
# 2        images3.jpg   0   0            0
# 3        images4.jpg   0   0            0
# 4        images5.jpg   1   0            1
# ...              ...  ..  ..          ...
# 1651  images1652.jpg   0   0            0
# 1652  images1653.jpg   0   0            0
# 1653  images1654.jpg   0   0            0
# 1654  images1655.jpg   0   0            0
# 1655  images1656.jpg   0   0            0
#
#                                                   Paths  \
# 0     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 2     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 3     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 4     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...                                                 ...
# 1651  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
trail
# Out:
#                  key TF TI AddedValues  \
# 0        images1.jpg  0  0           0
# 1        images2.jpg  1  0           1
# 2        images3.jpg  0  0           0
# 3        images4.jpg  0  0           0
# 4        images5.jpg  1  0           1
# ...              ... .. ..         ...
# 1651  images1652.jpg  0  0           0
# 1652  images1653.jpg  0  0           0
# 1653  images1654.jpg  0  0           0
# 1654  images1655.jpg  0  0           0
# 1655  images1656.jpg  0  0           0
#
#                                                   Paths
# 0     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 2     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 3     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 4     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...                                                 ...
# 1651  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
newOne =  pd.read_csv(fileCSV,
                       delimiter=',')
newOne.head(20) #First 20 rows printed
# Out:
#              key  TF  TI  AddedValues  \
# 0    images1.jpg   0   0            0
# 1    images2.jpg   1   0            1
# 2    images3.jpg   0   0            0
# 3    images4.jpg   0   0            0
# 4    images5.jpg   1   0            1
# 5    images6.jpg   0   1            1
# 6    images7.jpg   0   0            0
# 7    images8.jpg   1   1            2
# 8    images9.jpg   0   0            0
# 9   images10.jpg   1   1            2
# 10  images11.jpg   1   0            1
# 11  images12.jpg   0   0            0
# 12  images13.jpg   0   0            0
# 13  images14.jpg   0   0            0
# 14  images15.jpg   1   0            1
# 15  images16.jpg   1   0            1
# 16  images17.jpg   0   0            0
# 17  images18.jpg   0   0            0
# 18  images19.jpg   0   0            0
# 19  images20.jpg   1   0            1
#
#                                                 Paths  \
# 0   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
def separate(df):
    if df.AddedValues > 0:
        return df.Paths
    return
#Get paths function

# %%
newOne['trachomapaths'] = newOne[['AddedValues','Paths']].apply(separate, axis=1)
#Axis 1 = row, Axis 0 = column
newOne.Normalpaths = newOne[['AddedValues','Paths']].apply(lambda df: df.Paths if df.AddedValues==0 else '', axis=1)

# %%
newOne.head(20)
# Out:
#              key  TF  TI  AddedValues  \
# 0    images1.jpg   0   0            0
# 1    images2.jpg   1   0            1
# 2    images3.jpg   0   0            0
# 3    images4.jpg   0   0            0
# 4    images5.jpg   1   0            1
# 5    images6.jpg   0   1            1
# 6    images7.jpg   0   0            0
# 7    images8.jpg   1   1            2
# 8    images9.jpg   0   0            0
# 9   images10.jpg   1   1            2
# 10  images11.jpg   1   0            1
# 11  images12.jpg   0   0            0
# 12  images13.jpg   0   0            0
# 13  images14.jpg   0   0            0
# 14  images15.jpg   1   0            1
# 15  images16.jpg   1   0            1
# 16  images17.jpg   0   0            0
# 17  images18.jpg   0   0            0
# 18  images19.jpg   0   0            0
# 19  images20.jpg   1   0            1
#
#                                                 Paths  \
# 0   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
newOne.to_csv(fileCSV,index= False)

# %%
#Now to to get the data into the file
#Startgin with the healthy

# %%
healthyCSVPath = '/Users/swathikakarala/Desktop/Sirihaasa/healthyCSV.csv'

# %%
healthyCSVdf =  pd.read_csv(healthyCSVPath,
                       delimiter=',')
healthyCSVdf.head(20) #First 20 rows printed
# Out:
#                                           Normalpaths
# 0   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 2   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 3   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 4   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 5   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 6   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 7   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 8   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 9   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 10  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 11  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 12  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 13  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 14  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 15  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
healthyLoc = '/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/healthyEylid'

# %%
for i in healthyCSVdf.Normalpaths:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store
    with open(healthyLoc, 'wb') as f: #Write it as file, and append location
        f.write(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-304-74876a088302> in <module>
#       1 for i in healthyCSVdf.Normalpaths:
# ----> 2     with open(i, 'rb') as f: #REad the file path
#       3         data = f.read() #REad and store
#       4     with open(healthyLoc, 'wb') as f: #Write it as file, and append location
#       5         f.write(data)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/trachomaoverall/images1.jpg'

# %%
new =  pd.read_csv(fileCSV,
                       delimiter=',')
new.head(20) #First 20 rows printed
# Out:
#     key  TF  TI  AddedValues  Paths  healthyPath  tPath
# 0     1   0   0            0    NaN          NaN    NaN
# 1     2   1   0            1    NaN          NaN    NaN
# 2     3   0   0            0    NaN          NaN    NaN
# 3     4   0   0            0    NaN          NaN    NaN
# 4     5   1   0            1    NaN          NaN    NaN
# 5     6   0   1            1    NaN          NaN    NaN
# 6     7   0   0            0    NaN          NaN    NaN
# 7     8   1   1            2    NaN          NaN    NaN
# 8     9   0   0            0    NaN          NaN    NaN
# 9    10   1   1            2    NaN          NaN    NaN
# 10   11   1   0            1    NaN          NaN    NaN
# 11   12   0   0            0    NaN          NaN    NaN
# 12   13   0   0            0    NaN          NaN    NaN
# 13   14   0   0            0    NaN          NaN    NaN
# 14   15   1   0            1    NaN          NaN    NaN
# 15   16   1   0            1    NaN          NaN    NaN
# ...

# %%
new = new.applymap(str)

# %%
new['key'] = "image"+new['key']+'.jpg'

# %%
new
# Out:
#                 key TF TI AddedValues Paths healthyPath tPath
# 0        image1.jpg  0  0           0   nan         nan   nan
# 1        image2.jpg  1  0           1   nan         nan   nan
# 2        image3.jpg  0  0           0   nan         nan   nan
# 3        image4.jpg  0  0           0   nan         nan   nan
# 4        image5.jpg  1  0           1   nan         nan   nan
# ...             ... .. ..         ...   ...         ...   ...
# 1651  image1652.jpg  0  0           0   nan         nan   nan
# 1652  image1653.jpg  0  0           0   nan         nan   nan
# 1653  image1654.jpg  0  0           0   nan         nan   nan
# 1654  image1655.jpg  0  0           0   nan         nan   nan
# 1655  image1656.jpg  0  0           0   nan         nan   nan
#
# [1656 rows x 7 columns]

# %%
def separate(df):
    if df.AddedValues > 0:
        return df.Paths
    return
#Get paths function

# %%
new['trachomapaths'] = new[['AddedValues','Paths']].apply(separate, axis=1)
#Axis 1 = row, Axis 0 = column
new.Normalpaths = new[['AddedValues','Paths']].apply(lambda df: df.Paths if df.AddedValues==0 else '', axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-328-a0b955b01004> in <module>
# ----> 1 new['trachomapaths'] = new[['AddedValues','Paths']].apply(separate, axis=1)
#       2 #Axis 1 = row, Axis 0 = column
#       3 new.Normalpaths = new[['AddedValues','Paths']].apply(lambda df: df.Paths if df.AddedValues==0 else '', axis=1)
#
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     183             return self.apply_raw()
#     184
# --> 185         return self.apply_standard()
#     186
# ...

# %%
new['AddedValues'] = new['AddedValues'].astype(int)

# %%
new
# Out:
#                 key TF TI  AddedValues Paths healthyPath tPath
# 0        image1.jpg  0  0            0   nan         nan   nan
# 1        image2.jpg  1  0            1   nan         nan   nan
# 2        image3.jpg  0  0            0   nan         nan   nan
# 3        image4.jpg  0  0            0   nan         nan   nan
# 4        image5.jpg  1  0            1   nan         nan   nan
# ...             ... .. ..          ...   ...         ...   ...
# 1651  image1652.jpg  0  0            0   nan         nan   nan
# 1652  image1653.jpg  0  0            0   nan         nan   nan
# 1653  image1654.jpg  0  0            0   nan         nan   nan
# 1654  image1655.jpg  0  0            0   nan         nan   nan
# 1655  image1656.jpg  0  0            0   nan         nan   nan
#
# [1656 rows x 7 columns]

# %%
new['Paths']='/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/trachomaoverall/'+ new['key']

# %%
new
# Out:
#                 key TF TI  AddedValues  \
# 0        image1.jpg  0  0            0
# 1        image2.jpg  1  0            1
# 2        image3.jpg  0  0            0
# 3        image4.jpg  0  0            0
# 4        image5.jpg  1  0            1
# ...             ... .. ..          ...
# 1651  image1652.jpg  0  0            0
# 1652  image1653.jpg  0  0            0
# 1653  image1654.jpg  0  0            0
# 1654  image1655.jpg  0  0            0
# 1655  image1656.jpg  0  0            0
#
#                                                   Paths healthyPath tPath
# 0     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...         nan   nan
# 1     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...         nan   nan
# 2     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...         nan   nan
# 3     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...         nan   nan
# 4     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...         nan   nan
# ...

# %%
new['tPath'] = new[['AddedValues','Paths']].apply(separate, axis=1)
#Axis 1 = row, Axis 0 = column
new.healthyPath = new[['AddedValues','Paths']].apply(lambda df: df.Paths if df.AddedValues==0 else '', axis=1)

# %%
new
# Out:
#                 key TF TI  AddedValues  \
# 0        image1.jpg  0  0            0
# 1        image2.jpg  1  0            1
# 2        image3.jpg  0  0            0
# 3        image4.jpg  0  0            0
# 4        image5.jpg  1  0            1
# ...             ... .. ..          ...
# 1651  image1652.jpg  0  0            0
# 1652  image1653.jpg  0  0            0
# 1653  image1654.jpg  0  0            0
# 1654  image1655.jpg  0  0            0
# 1655  image1656.jpg  0  0            0
#
#                                                   Paths  \
# 0     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 2     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 3     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 4     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...                                                 ...
# 1651  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
new.to_csv(fileCSV,
                       index=False)

# %%
new
# Out:
#                 key TF TI  AddedValues  \
# 0        image1.jpg  0  0            0
# 1        image2.jpg  1  0            1
# 2        image3.jpg  0  0            0
# 3        image4.jpg  0  0            0
# 4        image5.jpg  1  0            1
# ...             ... .. ..          ...
# 1651  image1652.jpg  0  0            0
# 1652  image1653.jpg  0  0            0
# 1653  image1654.jpg  0  0            0
# 1654  image1655.jpg  0  0            0
# 1655  image1656.jpg  0  0            0
#
#                                                   Paths  \
# 0     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 2     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 3     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 4     /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...                                                 ...
# 1651  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
healty = '/Users/swathikakarala/Desktop/Sirihaasa/healthyCSV.csv'

# %%
hel =  pd.read_csv(healty,
                       delimiter=',')
hel.head(20) #First 20 rows printed
# Out:
#                                           healthyPath
# 0   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 2   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 3   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 4   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 5   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 6   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 7   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 8   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 9   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 10  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 11  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 12  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 13  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 14  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 15  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
healthyLoc = '/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/healthyEylid/'

# %%
for i in hel.healthyPath:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store
    # get fine name
    img = i.split('/')[-1]
    with open(healthyLoc+img, 'wb') as f: #Write it as file, and append location
        f.write(data)

# %%
for i in hel.healthyPath:
    print(i)
# Out:
# image1.jpg
# image3.jpg
# image4.jpg
# image7.jpg
# image9.jpg
# image12.jpg
# image13.jpg
# image14.jpg
# image17.jpg
# image18.jpg
# image19.jpg
# image21.jpg
# image22.jpg
# image23.jpg
# image25.jpg
# image26.jpg
# image29.jpg
# image30.jpg
# image31.jpg
# image33.jpg
# image34.jpg
# image37.jpg
# image44.jpg
# image46.jpg
# image48.jpg
# image49.jpg
# image53.jpg
# image54.jpg
# image55.jpg
# image56.jpg
# image57.jpg
# image58.jpg
# image59.jpg
# image61.jpg
# image62.jpg
# image63.jpg
# image65.jpg
# image66.jpg
# image67.jpg
# image68.jpg
# image72.jpg
# image74.jpg
# image75.jpg
# image76.jpg
# image78.jpg
# image79.jpg
# image80.jpg
# image81.jpg
# image85.jpg
# image86.jpg
# image87.jpg
# image88.jpg
# image89.jpg
# image90.jpg
# image91.jpg
# image94.jpg
# image95.jpg
# image96.jpg
# image97.jpg
# image98.jpg
# image100.jpg
# image102.jpg
# image106.jpg
# image108.jpg
# image109.jpg
# image110.jpg
# image111.jpg
# image112.jpg
# image113.jpg
# image114.jpg
# image118.jpg
# ...

# %%
tpath = '/Users/swathikakarala/Desktop/Sirihaasa/trachoma.csv'

# %%
tr =  pd.read_csv(tpath,
                       delimiter=',')
tr.head(20) #First 20 rows printed
# Out:
#                                                  path
# 0   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 1   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 2   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 3   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 4   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 5   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 6   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 7   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 8   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 9   /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 10  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 11  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 12  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 13  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 14  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# 15  /Users/swathikakarala/Desktop/Sirihaasa/Indepe...
# ...

# %%
tloc = '/Users/swathikakarala/Desktop/Sirihaasa/Independent_Study_Machine_Learning/DatasetMachineLearning_EyeDisease/Training_Dataset/trachomaDatasettfti'

# %%
for i in path.tr:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-379-7844d2374776> in <module>
# ----> 1 for i in path.tr:
#       2     print(i)
#
# NameError: name 'path' is not defined

# %%
for i in tr.path:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store
    # get fine name, just eh 'image part', like image6
    img = i.split('/')[-1]
    with open(tloc+img, 'wb') as f: #Write it as file, and append location
        f.write(data)

# %%
use the coe above
