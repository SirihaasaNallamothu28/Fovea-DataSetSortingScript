# %%
#Split the file into two
#Right eyes w/t targets and left eyes with target
#Right eye up untill

#First read the overal df into the code
import pandas as pd
allData =  pd.read_csv('C:\\Users\\SateeshSwathi\Documents\kaggleEyedataset\\full_df.csv',
                       delimiter=',')
allData.head(20) #First 20 rows printed
#We will focus on target for right and left eye
#Cant use file path must append to file name
# Out:
#     ID  Patient Age Patient Sex  Left-Fundus  Right-Fundus  \
# 0    0           69      Female   0_left.jpg   0_right.jpg
# 1    1           57        Male   1_left.jpg   1_right.jpg
# 2    2           42        Male   2_left.jpg   2_right.jpg
# 3    4           53        Male   4_left.jpg   4_right.jpg
# 4    5           50      Female   5_left.jpg   5_right.jpg
# 5    6           60        Male   6_left.jpg   6_right.jpg
# 6    7           60      Female   7_left.jpg   7_right.jpg
# 7    8           59        Male   8_left.jpg   8_right.jpg
# 8    9           54        Male   9_left.jpg   9_right.jpg
# 9   10           70        Male  10_left.jpg  10_right.jpg
# 10  11           60      Female  11_left.jpg  11_right.jpg
# 11  13           60      Female  13_left.jpg  13_right.jpg
# 12  14           55        Male  14_left.jpg  14_right.jpg
# 13  15           50        Male  15_left.jpg  15_right.jpg
# 14  16           54      Female  16_left.jpg  16_right.jpg
# ...

# %%
#The right eye file load in:
rightEye = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightEye.csv', delimiter = ',')

# %%
#Will copy the first 3195 rows
rightEye = allData.head(3193)

# %%
rightEye #This is the ouput afterwords, I acideently reran it
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 0        0           69      Female     0_left.jpg     0_right.jpg
# 1        1           57        Male     1_left.jpg     1_right.jpg
# 2        2           42        Male     2_left.jpg     2_right.jpg
# 3        4           53        Male     4_left.jpg     4_right.jpg
# 4        5           50      Female     5_left.jpg     5_right.jpg
# ...    ...          ...         ...            ...             ...
# 3188  4683           58        Male  4683_left.jpg  4683_right.jpg
# 3189  4686           63        Male  4686_left.jpg  4686_right.jpg
# 3190  4688           42        Male  4688_left.jpg  4688_right.jpg
# 3191  4689           54        Male  4689_left.jpg  4689_right.jpg
# 3192  4690           57        Male  4690_left.jpg  4690_right.jpg
#
#                                Left-Diagnostic Keywords  \
# 0                                              cataract
# ...

# %%
#Save into file: 
rightEye.to_csv('C:\\Users\\SateeshSwathi\\Documents\\rightEye.csv',
                       index=False)

# %%
#The left eye file:
leftEye = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\leftEye.csv', delimiter = ',')

leftEye
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 0        0           69      Female     0_left.jpg     0_right.jpg
# 1        1           57        Male     1_left.jpg     1_right.jpg
# 2        3           66        Male     3_left.jpg     3_right.jpg
# 3        4           53        Male     4_left.jpg     4_right.jpg
# 4        5           50      Female     5_left.jpg     5_right.jpg
# ...    ...          ...         ...            ...             ...
# 3193  4686           63        Male  4686_left.jpg  4686_right.jpg
# 3194  4688           42        Male  4688_left.jpg  4688_right.jpg
# 3195  4689           54        Male  4689_left.jpg  4689_right.jpg
# 3196  4690           57        Male  4690_left.jpg  4690_right.jpg
# 3197  4784           58        Male  4784_left.jpg  4784_right.jpg
#
#                                Left-Diagnostic Keywords  \
# 0                                              cataract
# ...

# %%
leftEye = allData.tail(3198)

leftEye
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 3194     0           69      Female     0_left.jpg     0_right.jpg
# 3195     1           57        Male     1_left.jpg     1_right.jpg
# 3196     3           66        Male     3_left.jpg     3_right.jpg
# 3197     4           53        Male     4_left.jpg     4_right.jpg
# 3198     5           50      Female     5_left.jpg     5_right.jpg
# ...    ...          ...         ...            ...             ...
# 6387  4686           63        Male  4686_left.jpg  4686_right.jpg
# 6388  4688           42        Male  4688_left.jpg  4688_right.jpg
# 6389  4689           54        Male  4689_left.jpg  4689_right.jpg
# 6390  4690           57        Male  4690_left.jpg  4690_right.jpg
# 6391  4784           58        Male  4784_left.jpg  4784_right.jpg
#
#                                Left-Diagnostic Keywords  \
# 3194                                           cataract
# ...

# %%
leftEye.to_csv('C:\\Users\\SateeshSwathi\\Documents\\leftEye.csv',
                       index=False)

# %%
#Look into the file paths
#Right eye Ex: C:\\Users\\SateeshSwathi\\Documents\\kaggleEyedataset\\preprocessed_images\\+ file name hrere
#Append the following to the colun 'filename'
#Fix this is doing it twice figure out how to delte and what is goin gon
rightEye['name'] = 'C:\\Users\\SateeshSwathi\\Documents\\kaggleEyedataset\\preprocessed_images\\' + rightEye['filename']
rightEye
# Out:
# C:\Users\SateeshSwathi\Miniconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 0        0           69      Female     0_left.jpg     0_right.jpg
# 1        1           57        Male     1_left.jpg     1_right.jpg
# 2        2           42        Male     2_left.jpg     2_right.jpg
# 3        4           53        Male     4_left.jpg     4_right.jpg
# 4        5           50      Female     5_left.jpg     5_right.jpg
# ...    ...          ...         ...            ...             ...
# 3188  4683           58        Male  4683_left.jpg  4683_right.jpg
# ...

# %%
rightEye.to_csv('C:\\Users\\SateeshSwathi\\Documents\\rightEye.csv',
                       index=False)
#don't rerun above cells

# %%
#../input/ocular-disease-recognition-odir5k/ODIR-5K/Training Images/14_right.jpg
#Firx the path of the folder
#Complete- do not rerun

# %%
#Start with the Right Eye
#I will iterate through 
#N	D	G	C	A	H	M	O
#N  normal,  D = Diabetic Retinopathy, G = Gloucoma, C = Cataract,A= AMD H = Hypertension , M = Mypia, 0= Other disease
#[N,D,G,C,A,H,M,O]
#Focus on the column called target for the right eye
#Whichever index has a 1 that is what it is sorted into4
#The file paths are in the column called 'name'
#The target as an array for right 


#Take the file paths and put it in the approiate column in righteyfiles
#I made columns into it
#REad in Right eye files
#rightEyeFiles = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightEyeFiles.csv', delimiter = ',')
#rightEyeFiles #Use this to transfer the file names of normal, diabtirc retinopatyy

# %%
rightEye.head(10)
# Out:
#    ID  Patient Age Patient Sex  Left-Fundus  Right-Fundus  \
# 0   0           69      Female   0_left.jpg   0_right.jpg
# 1   1           57        Male   1_left.jpg   1_right.jpg
# 2   2           42        Male   2_left.jpg   2_right.jpg
# 3   4           53        Male   4_left.jpg   4_right.jpg
# 4   5           50      Female   5_left.jpg   5_right.jpg
# 5   6           60        Male   6_left.jpg   6_right.jpg
# 6   7           60      Female   7_left.jpg   7_right.jpg
# 7   8           59        Male   8_left.jpg   8_right.jpg
# 8   9           54        Male   9_left.jpg   9_right.jpg
# 9  10           70        Male  10_left.jpg  10_right.jpg
#
#                             Left-Diagnostic Keywords  \
# 0                                           cataract
# 1                                      normal fundus
# 2  laser spot，moderate non proliferative retinopathy
# 3                        macular epiretinal membrane
# 4             moderate non proliferative retinopathy
# ...

# %%
#For each target in the column if: 
#index = 0 put the value in the Normal File
#index = 1 = put in diabetic Retinopathy file 
#index = 2 put in Cataracts
#index = 3= aMD
#index = 4 = Hyptertension 
#Myopia = index = 5
#other diseases = Other disease
#Using labels instead of array

#N  normal,  D = Diabetic Retinopathy, G = Gloucoma, C = Cataract,A= AMD H = Hypertension , M = Mypia, 0= Other disease
#[N,D,G,C,A,H,M,O]

rightNormal = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightNormal.csv',
                       delimiter=',')

N_name = rightEye[rightEye.labels=="['N']"]['name']  #Using the query method to search every individual column in in labels for N
#Assigining the value 'name', which is a file path to n name, and putting it in this columns
rightNormal['Normal'] = N_name

rightNormal
#done
# Out:
#                                                  Normal
# 0     C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1     C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1399                                                NaN
# 1400                                                NaN
# 1401                                                NaN
# 1402                                                NaN
# 1403                                                NaN
#
# [1404 rows x 1 columns]

# %%
rightNormal.to_csv('C:\\Users\\SateeshSwathi\\Documents\\rightNormal.csv',
                       index=False)
#Use the RightNormal for normal right eye files, don't change

# %%
rightDiabeticRetinopathy =pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightDiabeticRetinopathy.csv',
                       delimiter=',')
D_Name = rightEye[rightEye.labels=="['D']"]['name']
rightDiabeticRetinopathy['Diabetic Retinopathy'] = D_name

rightDiabeticRetinopathy
# Out:
#                                    Diabetic Retinopathy
# 2     C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3     C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 4     C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 5     C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 6     C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# ...                                                 ...
# 3187  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3188  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3189  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3190  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3192  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
#
# [820 rows x 1 columns]

# %%
rightDiabeticRetinopathy.to_csv('C:\\Users\\SateeshSwathi\\Documents\\rightDiabeticRetinopathy.csv',
                       index=False)

# %%
rightGlaucoma = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightGlaucoma.csv',
                       delimiter=',')


G_Name = rightEye[rightEye.labels=="['G']"]['name']
rightGlaucoma['Glaucoma'] = G_name

rightGlaucoma
# Out:
#                                                Glaucoma
# 141   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 510   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 648   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 804   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 986   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# ...                                                 ...
# 1340  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1342  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1346  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1360  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1362  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
#
# [129 rows x 1 columns]

# %%
rightGlaucoma.to_csv('C:\\Users\\SateeshSwathi\\Documents\\rightGlaucoma.csv',
                       index=False)

# %%
#C = Cataract,A= AMD H = Hypertension , M = Mypia, 0= Other disease
#[N,D,G,C,A,H,M,O]
rightCataracts = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightCataracts.csv',
                       delimiter=',')


C_Name = rightEye[rightEye.labels=="['C']"]['name']
rightCataracts['Cataract'] = C_Name

rightCataracts
# Out:
#                                                Cataract
# 20    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 93    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 160   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 186   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 309   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# ...                                                 ...
# 1506  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1507  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1508  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1509  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1511  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
#
# [143 rows x 1 columns]

# %%
rightCataracts.to_csv('C:\\Users\\SateeshSwathi\\Documents\\rightCataracts.csv',
                       index=False)

# %%
#A= AMD H = Hypertension , M = Mypia, 0= Other disease
#[N,D,G,C,A,H,M,O]
rightAMD = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightAMD.csv',
                       delimiter=',')


A_Name = rightEye[rightEye.labels=="['A']"]['name']
rightAMD['AMD'] = A_Name

rightAMD
# Out:
#                                                     AMD
# 34    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 39    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 44    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 46    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 57    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# ...                                                 ...
# 1332  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1334  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1335  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1336  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1337  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
#
# [137 rows x 1 columns]

# %%
rightAMD.to_csv('C:\\Users\\SateeshSwathi\\Documents\\rightAMD.csv',
                       index=False)

# %%
#H = Hypertension , M = Mypia, 0= Other disease
#[N,D,G,C,A,H,M,O]
rightHypers = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightHypertension.csv',
                       delimiter=',')


H_Name = rightEye[rightEye.labels=="['H']"]['name']
rightHypers['Ocular Hypertension'] = H_Name

rightHypers
# Out:
#                                     Ocular Hypertension
# 19    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 23    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 26    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 36    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 51    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# ...                                                 ...
# 3089  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3105  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3107  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3117  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3118  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
#
# [65 rows x 1 columns]

# %%
rightHypers.to_csv('C:\\Users\\SateeshSwathi\\Documents\\rightHypertension.csv',
                       index=False)

# %%
 #M = Mypia, 0= Other disease, don't need other diseases
#[N,D,G,C,A,H,M,O]
rightMyopia= pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightMyopia.csv',
                       delimiter=',')


M_Name = rightEye[rightEye.labels=="['M']"]['name']
rightMyopia['Myopia'] = M_Name

rightMyopia
# Out:
#                                                  Myopia
# 11    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 14    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 16    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 37    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 70    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# ...                                                 ...
# 1280  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1281  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1282  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1283  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1284  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
#
# [121 rows x 1 columns]

# %%
rightMyopia.to_csv('C:\\Users\\SateeshSwathi\\Documents\\rightMyopia.csv',
                       index=False)

# %%
#Now to take the file paths and actually put them into their respective folders

test_file = rightMyopia.Myopia[11]
location = 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\Myopia\\'

# %%
test_file.split('\\')[-1] #To get the last part
# Out:
# '13_right.jpg'

# %%
location+test_file.split('\\')[-1]
# Out:
# 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\Myopia\\13_right.jpg'

# %%
# read each file and write to target folder
#Sample
with open(test_file, 'rb') as f:
    data = f.read()

with open(location+test_file.split('\\')[-1], 'wb') as f:
    f.write(data)

# %%
for i in rightMyopia.Myopia:
    with open(i, 'rb') as f:
        data = f.read()

    with open(location+i.split('\\')[-1], 'wb') as f:
        f.write(data)

# %%
newLocation = 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\AMD\\'

# %%
for i in rightAMD.AMD: #For each file path in AMD
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store

    with open(newLocation+i.split('\\')[-1], 'wb') as f: #Write it as file, and append location
        f.write(data)

# %%
#finish, Done with AMD and Myopia GlaucomaDiaetic retinopathy,cataracts, hypertension, Normal 7 categories,

# %%
import pandas as pd
newLocation24 = 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\Glaucoma\\'
rightGlaucoma = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightGlaucoma.csv',
                       delimiter=',')

for i in rightGlaucoma.Glaucoma:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store

    with open(newLocation24+i.split('\\')[-1], 'wb') as f: #Write it as file, and append location
        f.write(data)

# %%
rightDiabeticRetinopathy = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightDiabeticRetinopathy.csv',
                       delimiter=',')
looction = 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\\Diabetic_Retinopathy\\'
rightGlaucoma = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightGlaucoma.csv',
                       delimiter=',')

for i in rightDiabeticRetinopathy.DiabeticRetinopathy:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store

    with open(looction+i.split('\\')[-1], 'wb') as f: #Write it as file, and append location
        f.write(data)

# %%
rightCataracts = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightCataracts.csv',
                       delimiter=',')
looctiona = 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\\Cataracts\\'


for i in rightCataracts.Cataract:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store

    with open(looctiona+i.split('\\')[-1], 'wb') as f: #Write it as file, and append location
        f.write(data)

# %%
rightHypertension = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightHypertension.csv',
                       delimiter=',')
looctionas = 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\\Ocular_Hypertension\\'


for i in rightHypertension.OcularHypertension:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store

    with open(looctionas+i.split('\\')[-1], 'wb') as f: #Write it as file, and append location
        f.write(data)

# %%
rightNormal = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\rightNormal.csv',
                       delimiter=',')
looctionasy = 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\Normal\\'


for i in rightNormal.Normal:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store

    with open(looctionasy+i.split('\\')[-1], 'wb') as f: #Write it as file, and append location
        f.write(data)

# %%
# All files loaded in for left now to do the right

# %%
import pandas as pd # incase you need to load again

# %%
#The left eye file:
leftEye = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\leftEye.csv', delimiter = ',')

leftEye #Using this file to traverse through and split into another dataframe
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 0        0           69      Female     0_left.jpg     0_right.jpg
# 1        1           57        Male     1_left.jpg     1_right.jpg
# 2        3           66        Male     3_left.jpg     3_right.jpg
# 3        4           53        Male     4_left.jpg     4_right.jpg
# 4        5           50      Female     5_left.jpg     5_right.jpg
# ...    ...          ...         ...            ...             ...
# 3193  4686           63        Male  4686_left.jpg  4686_right.jpg
# 3194  4688           42        Male  4688_left.jpg  4688_right.jpg
# 3195  4689           54        Male  4689_left.jpg  4689_right.jpg
# 3196  4690           57        Male  4690_left.jpg  4690_right.jpg
# 3197  4784           58        Male  4784_left.jpg  4784_right.jpg
#
#                                Left-Diagnostic Keywords  \
# 0                                              cataract
# ...

# %%
#Left eye normal read in


leftNormals = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\leftNormal.csv')
leftNormals
# Out:
# Empty DataFrame
# Columns: [LeftNormal]
# Index: []

# %%
#append path
leftEye['name'] = 'C:\\Users\\SateeshSwathi\\Documents\\kaggleEyedataset\\preprocessed_images\\' + leftEye['filename']
leftEye
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 0        0           69      Female     0_left.jpg     0_right.jpg
# 1        1           57        Male     1_left.jpg     1_right.jpg
# 2        3           66        Male     3_left.jpg     3_right.jpg
# 3        4           53        Male     4_left.jpg     4_right.jpg
# 4        5           50      Female     5_left.jpg     5_right.jpg
# ...    ...          ...         ...            ...             ...
# 3193  4686           63        Male  4686_left.jpg  4686_right.jpg
# 3194  4688           42        Male  4688_left.jpg  4688_right.jpg
# 3195  4689           54        Male  4689_left.jpg  4689_right.jpg
# 3196  4690           57        Male  4690_left.jpg  4690_right.jpg
# 3197  4784           58        Male  4784_left.jpg  4784_right.jpg
#
#                                Left-Diagnostic Keywords  \
# 0                                              cataract
# ...

# %%
leftEye.to_csv('C:\\Users\\SateeshSwathi\\Documents\\lefttEye.csv',
                       index=False)
#don't rerun above cells

# %%
N_name = leftEye[leftEye.labels=="['N']"]['name']  #Using the query method to search every individual column in in labels for N
#Assigining the value 'name', which is a file path to n name, and putting it in this columns
leftNormals['LeftNormal'] = N_name

leftNormals
#done
# Out:
#                                              LeftNormal
# 1     C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 2     C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 7     C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 8     C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 12    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# ...                                                 ...
# 3162  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3164  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3166  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3184  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3192  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
#
# [1469 rows x 1 columns]

# %%
leftNormals.to_csv('C:\\Users\\SateeshSwathi\\Documents\\leftNormal.csv',
                       index=False)
#don't rerun above cells

# %%
newLocation = 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\Normal\\'

for i in leftNormals.LeftNormal:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store

    with open(newLocation+i.split('\\')[-1], 'wb') as f: #Write it as file, and append location
        f.write(data)

# %%
#HyperTension
leftHypertension = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\leftHypertension.csv')
H_name = leftEye[leftEye.labels=="['H']"]['name']  #Using the query method to search every individual column in in labels for N
#Assigining the value 'name', which is a file path to n name, and putting it in this columns
leftHypertension['hypertension'] = H_name

leftHypertension
# Out:
#                                            hypertension
# 20    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 25    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 28    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 39    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 54    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# ...                                                 ...
# 3092  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3108  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3109  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3120  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3197  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
#
# [62 rows x 1 columns]

# %%
leftHypertension.to_csv('C:\\Users\\SateeshSwathi\\Documents\\leftHypertension.csv',
                       index=False)

# %%
newLocationHyper = 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\Ocular_Hypertension\\'

for i in leftHypertension.hypertension:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store

    with open(newLocationHyper+i.split('\\')[-1], 'wb') as f: #Write it as file, and append location
        f.write(data)

# %%
#Myopia


leftMyopia = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\leftMyopia.csv')
M_name = leftEye[leftEye.labels=="['M']"]['name']  #Using the query method to search every individual column in in labels for N
#Assigining the value 'name', which is a file path to n name, and putting it in this columns
leftMyopia['Myopia'] = M_name

leftMyopia
# Out:
#                                                  Myopia
# 11    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 16    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 31    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 33    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 90    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# ...                                                 ...
# 1273  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1278  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1280  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1281  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1283  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
#
# [111 rows x 1 columns]

# %%
leftMyopia.to_csv('C:\\Users\\SateeshSwathi\\Documents\\leftMyopia.csv',
                       index=False)

# %%
newLocationopi = 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\Myopia\\'

for i in leftMyopia.Myopia:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store

    with open(newLocationopi+i.split('\\')[-1], 'wb') as f: #Write it as file, and append location
        f.write(data)

# %%
#Glaucoma


leftGlaucoma = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\leftGlaucoma.csv')
G_name = leftEye[leftEye.labels=="['G']"]['name']  #Using the query method to search every individual column in in labels for N
#Assigining the value 'name', which is a file path to n name, and putting it in this columns
leftGlaucoma['Glaucoma'] = G_name

leftGlaucoma
# Out:
#                                                Glaucoma
# 80    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 132   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 146   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 501   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 648   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# ...                                                 ...
# 1343  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1353  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1356  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1360  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1365  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
#
# [155 rows x 1 columns]

# %%
leftGlaucoma.to_csv('C:\\Users\\SateeshSwathi\\Documents\\leftGlaucoma.csv',
                       index=False)

# %%
newLocationopiy = 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\Glaucoma\\'

for i in leftGlaucoma.Glaucoma:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store

    with open(newLocationopiy+i.split('\\')[-1], 'wb') as f: #Write it as file, and append location
        f.write(data)

# %%
leftRetinopathy = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\leftRetinopathy.csv')
D_name = leftEye[leftEye.labels=="['D']"]['name']  #Using the query method to search every individual column in in labels for N
#Assigining the value 'name', which is a file path to n name, and putting it in this columns
leftRetinopathy['Retinopathy'] = D_name

leftRetinopathy
# Out:
#                                             Retinopathy
# 4     C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 10    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 17    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 19    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 23    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# ...                                                 ...
# 3191  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3193  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3194  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3195  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 3196  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
#
# [788 rows x 1 columns]

# %%
leftRetinopathy.to_csv('C:\\Users\\SateeshSwathi\\Documents\\leftRetinopathy.csv',
                       index=False)

# %%
newLocationopimy = 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\Diabetic_Retinopathy\\'

for i in leftRetinopathy.Retinopathy:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store

    with open(newLocationopimy+i.split('\\')[-1], 'wb') as f: #Write it as file, and append location
        f.write(data)

# %%
leftCataracts = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\leftCataracts.csv')
C_name = leftEye[leftEye.labels=="['C']"]['name']  #Using the query method to search every individual column in in labels for N
#Assigining the value 'name', which is a file path to n name, and putting it in this columns
leftCataracts['Cataracts'] = C_name

leftCataracts
# Out:
#                                               Cataracts
# 0     C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 88    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 100   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 217   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 252   C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# ...                                                 ...
# 1503  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1504  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1505  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1506  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1507  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
#
# [150 rows x 1 columns]

# %%
leftCataracts.to_csv('C:\\Users\\SateeshSwathi\\Documents\\leftCataracts.csv',
                       index=False)

# %%
locationo= 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\Cataracts\\'

for i in leftCataracts.Cataracts:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store

    with open(locationo+i.split('\\')[-1], 'wb') as f: #Write it as file, and append location
        f.write(data)

# %%
leftAMDs = pd.read_csv('C:\\Users\\SateeshSwathi\\Documents\\leftAMD4546.csv')
A_name = leftEye[leftEye.labels=="['A']"]['name']  #Using the query method to search every individual column in in labels for N
#Assigining the value 'name', which is a file path to n name, and putting it in this columns
leftAMDs['AMD'] = A_name

leftAMDs
# Out:
#                                                     AMD
# 37    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 42    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 46    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 48    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 87    C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# ...                                                 ...
# 1328  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1329  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1355  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1359  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
# 1362  C:\Users\SateeshSwathi\Documents\kaggleEyedata...
#
# [129 rows x 1 columns]

# %%
leftAMDs.to_csv('C:\\Users\\SateeshSwathi\\Documents\\leftAMD4546.csv',
                       index=False)

# %%
locationos= 'C:\\Users\\SateeshSwathi\\Desktop\\DatasetMachineLearning_EyeDisease\\Training_Dataset\\AMD\\'

for i in leftAMDs.AMD:
    with open(i, 'rb') as f: #REad the file path
        data = f.read() #REad and store

    with open(locationos+i.split('\\')[-1], 'wb') as f: #Write it as file, and append location
        f.write(data)
